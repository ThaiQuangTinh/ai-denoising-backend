# %%
import csv

# Giả sử bạn đã có dữ liệu loss như sau:
train_losses = [0.1432, 0.0906, 0.0810, 0.0739, 0.0669, 0.0658, 0.0571, 0.0600, 0.0559, 0.0515,
                0.0535, 0.0538, 0.0499, 0.0488, 0.0483, 0.0469, 0.0468, 0.0439, 0.0441, 0.0460,
                0.0436, 0.0434, 0.0488, 0.0425, 0.0453]

val_losses = [0.0574, 0.0530, 0.0424, 0.0419, 0.0413, 0.0356, 0.0305, 0.0351, 0.0289, 0.0281,
              0.0648, 0.0253, 0.0221, 0.0209, 0.0276, 0.0190, 0.0196, 0.0210, 0.0184, 0.0185,
              0.0186, 0.0160, 0.0205, 0.0201, 0.0174]

csv_path = 'training_log.csv'

with open(csv_path, 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['Epoch', 'Train Loss', 'Val Loss'])
    for epoch, (train, val) in enumerate(zip(train_losses, val_losses), start=1):
        writer.writerow([epoch, train, val])

print(f"✅ Đã lưu kết quả training vào file: {csv_path}")
# Out:
# ✅ Đã lưu kết quả training vào file: training_log.csv

# %%
import matplotlib.pyplot as plt
import csv

epochs = []
train_losses = []
val_losses = []

csv_path = 'training_log.csv'
with open(csv_path, 'r') as f:
    reader = csv.DictReader(f)
    for row in reader:
        epochs.append(int(row['Epoch']))
        train_losses.append(float(row['Train Loss']))
        val_losses.append(float(row['Val Loss']))

# Plot
plt.figure(figsize=(10, 5))
plt.plot(epochs, train_losses, label='Train Loss')
plt.plot(epochs, val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss per Epoch')
plt.legend()
plt.grid(True)
plt.savefig('loss_curve.png')
plt.show()

print("📈 Đã vẽ và lưu biểu đồ loss tại: loss_curve.png")
# Out:
# 📈 Đã vẽ và lưu biểu đồ loss tại: loss_curve.png
